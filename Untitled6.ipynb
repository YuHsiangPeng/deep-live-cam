# %% [markdown]
# <a href="https://colab.research.google.com/github/YuHsiangPeng/deep-live-cam/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ultralytics import YOLOWorld
model = YOLOWorld("yolov8s-world.pt") # Changed model name to a standard downloadable one
results = model.predict("fcu.jpg")
results[0].show()
# Out:
# image 1/1 /content/fcu.jpg: 384x640 11 persons, 535.5ms
# Speed: 6.4ms preprocess, 535.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1152x648>
